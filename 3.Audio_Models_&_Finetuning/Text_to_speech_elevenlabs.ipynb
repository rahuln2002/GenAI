# %% [markdown]
# # T2S

# %%
# !pip install --quiet elevenlabs langchain langchain-openai langchain-together

# %% [markdown]
# ## ElevenLabs

# %%
from elevenlabs import generate, play, set_api_key

# %%
audio = generate(
    text = "Hello! I am Rahul! How are you?",
    # voice = "Adam"
    voice = "Rachel"
)
play(audio, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = generate(
    model = "eleven_multilingual_v2",
    text = "नमस्ते! मैं राहुल हूँ! आप कैसे हैं?",
    # voice = "Adam"
    voice = "Rachel"
)
play(audio, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## GPT

# %%
import os
from getpass import getpass
from langchain_openai import ChatOpenAI

# %%
os.environ['OPENAI_API_KEY'] = getpass("Enter OpenAI API key: ")

# %%
llm = ChatOpenAI(model_name = "gpt-3.5-turbo-0125")

# %%
def get_reply_in_voice(text):
    response = llm.invoke(text)
    audio = generate(
    text = response.content,
    voice = "Rachel"
    )
    play(audio, notebook = True)

# %%
get_reply_in_voice("Hi! How are you?")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
